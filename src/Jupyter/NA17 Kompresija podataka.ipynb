# %% [markdown]
# # Kompresija podataka
#
# ---
#
# QR rastav s pivotiranjem stupaca možemo koristiti za __kompresiju (sažimanje) podataka__.
#
# Dijagonalni elementi matrice $R$ padaju po apsolutnoj vrijednosti pa možemo odrezati djelove matrica $Q$ i $R$ za koje smatramo da nisu značajni.
#
# Dat ćemo primjer kompresije slike.

# %%
using Images
using LinearAlgebra
using Plots

# %%
img=load("P8040001a.jpg")
# Out:
# 576×768 Array{RGB{N0f8},2} with eltype RGB{Normed{UInt8,8}}:
#  RGB{N0f8}(0.439,0.624,0.843)  …  RGB{N0f8}(0.627,0.776,0.969)
#  RGB{N0f8}(0.447,0.631,0.851)     RGB{N0f8}(0.624,0.773,0.965)
#  RGB{N0f8}(0.439,0.624,0.843)     RGB{N0f8}(0.62,0.769,0.961)
#  RGB{N0f8}(0.435,0.62,0.839)      RGB{N0f8}(0.62,0.769,0.961)
#  RGB{N0f8}(0.447,0.631,0.851)     RGB{N0f8}(0.62,0.769,0.953)
#  RGB{N0f8}(0.443,0.627,0.847)  …  RGB{N0f8}(0.624,0.773,0.957)
#  RGB{N0f8}(0.435,0.62,0.839)      RGB{N0f8}(0.627,0.769,0.957)
#  RGB{N0f8}(0.443,0.627,0.847)     RGB{N0f8}(0.624,0.765,0.953)
#  RGB{N0f8}(0.451,0.635,0.855)     RGB{N0f8}(0.635,0.769,0.957)
#  RGB{N0f8}(0.451,0.635,0.855)     RGB{N0f8}(0.639,0.773,0.961)
#  RGB{N0f8}(0.451,0.635,0.855)  …  RGB{N0f8}(0.635,0.769,0.957)
#  RGB{N0f8}(0.455,0.639,0.859)     RGB{N0f8}(0.631,0.765,0.953)
#  RGB{N0f8}(0.451,0.635,0.855)     RGB{N0f8}(0.635,0.769,0.957)
#  ⋮                             ⋱
#  RGB{N0f8}(0.898,0.882,0.847)     RGB{N0f8}(0.267,0.459,0.584)
#  RGB{N0f8}(0.898,0.882,0.847)  …  RGB{N0f8}(0.267,0.459,0.584)
#  RGB{N0f8}(0.89,0.878,0.843)      RGB{N0f8}(0.271,0.463,0.588)
#  RGB{N0f8}(0.882,0.871,0.835)     RGB{N0f8}(0.251,0.443,0.569)
#  RGB{N0f8}(0.882,0.871,0.835)     RGB{N0f8}(0.263,0.455,0.58)
#  RGB{N0f8}(0.886,0.875,0.839)     RGB{N0f8}(0.255,0.447,0.573)
#  RGB{N0f8}(0.882,0.882,0.843)  …  RGB{N0f8}(0.275,0.455,0.584)
#  RGB{N0f8}(0.886,0.886,0.847)     RGB{N0f8}(0.271,0.451,0.58)
#  RGB{N0f8}(0.886,0.886,0.847)     RGB{N0f8}(0.275,0.451,0.573)
#  RGB{N0f8}(0.89,0.89,0.851)       RGB{N0f8}(0.302,0.478,0.6)
#  RGB{N0f8}(0.894,0.894,0.855)     RGB{N0f8}(0.306,0.482,0.604)
#  RGB{N0f8}(0.894,0.894,0.855)  …  RGB{N0f8}(0.294,0.471,0.592)

# %%
# Opis podataka
typeof(img)
# Out:
# Array{RGB{Normed{UInt8,8}},2}

# %%
img[1,1]
# Out:
# RGB{N0f8}(0.439,0.624,0.843)

# %%
show(img[1,1])
# Out:
# RGB{N0f8}(0.439,0.624,0.843)

# %%
# Razdvojimo sliku na R, G i B komponente
channels=channelview(img)
# Out:
# 3×576×768 reinterpret(N0f8, ::Array{RGB{N0f8},3}):
# [:, :, 1] =
#  0.439  0.447  0.439  0.435  0.447  …  0.886  0.886  0.89   0.894  0.894
#  0.624  0.631  0.624  0.62   0.631     0.886  0.886  0.89   0.894  0.894
#  0.843  0.851  0.843  0.839  0.851     0.847  0.847  0.851  0.855  0.855
#
# [:, :, 2] =
#  0.439  0.443  0.443  0.439  0.443  …  0.89   0.89   0.89   0.894  0.894
#  0.624  0.627  0.627  0.624  0.627     0.89   0.89   0.89   0.894  0.894
#  0.843  0.847  0.847  0.843  0.847     0.851  0.851  0.851  0.855  0.855
#
# [:, :, 3] =
#  0.443  0.439  0.447  0.447  0.439  …  0.906  0.898  0.898  0.902  0.902
#  0.627  0.624  0.631  0.631  0.624     0.894  0.898  0.898  0.902  0.902
#  0.847  0.843  0.851  0.851  0.843     0.859  0.859  0.859  0.863  0.863
#
# ...
#
# [:, :, 766] =
#  0.62   0.624  0.624  0.624  0.627  …  0.263  0.271  0.302  0.302  0.286
#  0.769  0.773  0.773  0.773  0.769     0.443  0.447  0.478  0.478  0.463
#  0.953  0.957  0.957  0.957  0.957     0.573  0.569  0.6    0.6    0.584
#
# [:, :, 767] =
#  0.624  0.624  0.62   0.62   0.624  …  0.271  0.275  0.302  0.302  0.286
#  0.773  0.773  0.769  0.769  0.773     0.451  0.451  0.478  0.478  0.463
#  0.965  0.965  0.961  0.961  0.957     0.58   0.573  0.6    0.6    0.584
#
# [:, :, 768] =
#  0.627  0.624  0.62   0.62   0.62   …  0.271  0.275  0.302  0.306  0.294
#  0.776  0.773  0.769  0.769  0.769     0.451  0.451  0.478  0.482  0.471
#  0.969  0.965  0.961  0.961  0.953     0.58   0.573  0.6    0.604  0.592

# %%
Red=channels[1,:,:]
Green=channels[2,:,:]
Blue=channels[3,:,:]
# Out:
# 576×768 Array{N0f8,2} with eltype Normed{UInt8,8}:
#  0.843  0.843  0.847  0.847  0.847  …  0.949  0.953  0.953  0.965  0.969
#  0.851  0.847  0.843  0.839  0.839     0.953  0.957  0.957  0.965  0.965
#  0.843  0.847  0.851  0.851  0.851     0.957  0.961  0.957  0.961  0.961
#  0.839  0.843  0.851  0.855  0.855     0.957  0.961  0.957  0.961  0.961
#  0.851  0.847  0.843  0.839  0.839     0.957  0.957  0.957  0.957  0.953
#  0.847  0.847  0.843  0.843  0.843  …  0.953  0.953  0.957  0.957  0.957
#  0.839  0.843  0.851  0.855  0.855     0.953  0.957  0.957  0.957  0.957
#  0.847  0.847  0.847  0.847  0.851     0.957  0.957  0.957  0.957  0.953
#  0.855  0.855  0.855  0.855  0.851     0.949  0.957  0.953  0.953  0.957
#  0.855  0.851  0.847  0.847  0.851     0.953  0.965  0.961  0.957  0.961
#  0.855  0.851  0.847  0.847  0.851  …  0.953  0.961  0.957  0.957  0.957
#  0.859  0.855  0.851  0.851  0.851     0.949  0.961  0.957  0.953  0.953
#  0.855  0.855  0.855  0.851  0.851     0.953  0.961  0.961  0.961  0.957
#  ⋮                                  ⋱                ⋮
#  0.847  0.851  0.855  0.859  0.855     0.592  0.592  0.592  0.588  0.584
#  0.847  0.851  0.855  0.855  0.851  …  0.6    0.588  0.576  0.58   0.584
#  0.843  0.847  0.855  0.855  0.847     0.596  0.584  0.58   0.584  0.588
#  0.835  0.839  0.847  0.851  0.847     0.588  0.596  0.592  0.58   0.569
#  0.835  0.839  0.847  0.859  0.855     0.576  0.576  0.573  0.573  0.58
#  0.839  0.843  0.851  0.863  0.859     0.576  0.576  0.573  0.569  0.573
#  0.843  0.847  0.855  0.867  0.863  …  0.58   0.58   0.58   0.584  0.584
#  0.847  0.851  0.859  0.871  0.867     0.569  0.561  0.573  0.58   0.58
#  0.847  0.851  0.859  0.871  0.871     0.573  0.565  0.569  0.573  0.573
#  0.851  0.851  0.859  0.871  0.871     0.612  0.6    0.6    0.6    0.6
#  0.855  0.855  0.863  0.871  0.871     0.612  0.608  0.6    0.6    0.604
#  0.855  0.855  0.863  0.875  0.871  …  0.604  0.596  0.584  0.584  0.592

# %%
colorview(Gray,Blue)
# Out:
# 576×768 reinterpret(Gray{N0f8}, ::Array{N0f8,2}):
#  Gray{N0f8}(0.843)  Gray{N0f8}(0.843)  …  Gray{N0f8}(0.969)
#  Gray{N0f8}(0.851)  Gray{N0f8}(0.847)     Gray{N0f8}(0.965)
#  Gray{N0f8}(0.843)  Gray{N0f8}(0.847)     Gray{N0f8}(0.961)
#  Gray{N0f8}(0.839)  Gray{N0f8}(0.843)     Gray{N0f8}(0.961)
#  Gray{N0f8}(0.851)  Gray{N0f8}(0.847)     Gray{N0f8}(0.953)
#  Gray{N0f8}(0.847)  Gray{N0f8}(0.847)  …  Gray{N0f8}(0.957)
#  Gray{N0f8}(0.839)  Gray{N0f8}(0.843)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.847)  Gray{N0f8}(0.847)     Gray{N0f8}(0.953)
#  Gray{N0f8}(0.855)  Gray{N0f8}(0.855)     Gray{N0f8}(0.957)
#  Gray{N0f8}(0.855)  Gray{N0f8}(0.851)     Gray{N0f8}(0.961)
#  Gray{N0f8}(0.855)  Gray{N0f8}(0.851)  …  Gray{N0f8}(0.957)
#  Gray{N0f8}(0.859)  Gray{N0f8}(0.855)     Gray{N0f8}(0.953)
#  Gray{N0f8}(0.855)  Gray{N0f8}(0.855)     Gray{N0f8}(0.957)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.847)  Gray{N0f8}(0.851)     Gray{N0f8}(0.584)
#  Gray{N0f8}(0.847)  Gray{N0f8}(0.851)  …  Gray{N0f8}(0.584)
#  Gray{N0f8}(0.843)  Gray{N0f8}(0.847)     Gray{N0f8}(0.588)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.839)     Gray{N0f8}(0.569)
#  Gray{N0f8}(0.835)  Gray{N0f8}(0.839)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.839)  Gray{N0f8}(0.843)     Gray{N0f8}(0.573)
#  Gray{N0f8}(0.843)  Gray{N0f8}(0.847)  …  Gray{N0f8}(0.584)
#  Gray{N0f8}(0.847)  Gray{N0f8}(0.851)     Gray{N0f8}(0.58)
#  Gray{N0f8}(0.847)  Gray{N0f8}(0.851)     Gray{N0f8}(0.573)
#  Gray{N0f8}(0.851)  Gray{N0f8}(0.851)     Gray{N0f8}(0.6)
#  Gray{N0f8}(0.855)  Gray{N0f8}(0.855)     Gray{N0f8}(0.604)
#  Gray{N0f8}(0.855)  Gray{N0f8}(0.855)  …  Gray{N0f8}(0.592)

# %%
# Izračunajmo QR rastav s pivotiranjem matrice svakog kanala
R=qr(Red,Val(true))
G=qr(Green,Val(true))
B=qr(Blue,Val(true));

# %%
norm(R.Q*R.R[:,invperm(R.p)]-float(Red))
# Out:
# 0.00019354107f0

# %%
# Nacrtajmo dijagonalne elemente
scatter(1:length(diag(R.R,1)),abs.(diag(R.R)),
    title="Diagonal elements of matrix R",legend=false)

# %%
# Izračunajmo komprimirane matrice za svaki kanal, RedC, GreenC i BlueC
# Funkcija Matrix() je nužna radi bržeg generiranja matrice Q
k=50
RedC=Matrix(R.Q)[:,1:k]*R.R[1:k,invperm(R.p)]
GreenC=Matrix(G.Q)[:,1:k]*G.R[1:k,invperm(G.p)]
BlueC=Matrix(B.Q)[:,1:k]*B.R[1:k,invperm(B.p)]
# Out:
# 576×768 Array{Float32,2}:
#  0.849221  0.849419  0.849613  0.848986  …  0.951224  0.951218  0.952345
#  0.850833  0.850977  0.851206  0.850909     0.951578  0.951396  0.951979
#  0.854566  0.855033  0.855641  0.854221     0.952285  0.952251  0.954134
#  0.856747  0.856969  0.857194  0.85476      0.952852  0.953513  0.954645
#  0.860758  0.860862  0.861023  0.859647     0.951365  0.952203  0.954199
#  0.859466  0.859761  0.860209  0.860274  …  0.949736  0.949304  0.950518
#  0.856315  0.856868  0.857974  0.858545     0.95499   0.953994  0.954867
#  0.853424  0.854004  0.854706  0.85662      0.959859  0.958582  0.957889
#  0.855778  0.856114  0.856438  0.858546     0.950206  0.948848  0.947465
#  0.857619  0.858369  0.858482  0.859991     0.956397  0.954145  0.952858
#  0.861171  0.862007  0.862343  0.86251   …  0.953244  0.951111  0.950526
#  0.862289  0.863157  0.863619  0.863754     0.949253  0.947282  0.946622
#  0.862025  0.862261  0.863018  0.862675     0.952245  0.951357  0.95138
#  ⋮                                       ⋱  ⋮
#  0.830461  0.836827  0.844145  0.868992     0.587633  0.583677  0.591088
#  0.834659  0.84023   0.84386   0.861923  …  0.606971  0.599432  0.607673
#  0.805795  0.812625  0.815761  0.833706     0.615465  0.607295  0.61448
#  0.770001  0.773336  0.780736  0.805385     0.594332  0.594826  0.599924
#  0.776333  0.776332  0.782551  0.800276     0.564783  0.568516  0.57376
#  0.760205  0.760071  0.766396  0.787358     0.577885  0.580483  0.578041
#  0.79876   0.802747  0.809234  0.820594  …  0.581729  0.583176  0.587865
#  0.806639  0.813227  0.821127  0.830241     0.589538  0.586436  0.595274
#  0.78402   0.789588  0.798363  0.812998     0.598583  0.591273  0.596178
#  0.803452  0.809523  0.813164  0.829251     0.623548  0.6102    0.606397
#  0.819525  0.827534  0.827292  0.838745     0.622337  0.604232  0.596663
#  0.809495  0.819074  0.821661  0.831876  …  0.613924  0.595012  0.585665

# %%
norm(Red-RedC)/norm(Red)
# Out:
# 0.10522057f0

# %%
# Nacrtajmo komprimiranu sliku
colorview(RGB, RedC, GreenC, BlueC)
# Out:
# 576×768 mappedarray(RGB{Float32}, ImageCore.extractchannels, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}) with eltype RGB{Float32}:
#  RGB{Float32}(0.439716,0.633219,0.849221)  …  RGB{Float32}(0.627447,0.775903,0.952345)
#  RGB{Float32}(0.437818,0.635481,0.850833)     RGB{Float32}(0.623531,0.775376,0.951979)
#  RGB{Float32}(0.44195,0.631935,0.854566)      RGB{Float32}(0.619608,0.771367,0.954134)
#  RGB{Float32}(0.446721,0.630725,0.856747)     RGB{Float32}(0.619608,0.770645,0.954645)
#  RGB{Float32}(0.446068,0.633028,0.860758)     RGB{Float32}(0.619608,0.773332,0.954199)
#  RGB{Float32}(0.443362,0.629011,0.859466)  …  RGB{Float32}(0.623529,0.773308,0.950518)
#  RGB{Float32}(0.44331,0.625261,0.856315)      RGB{Float32}(0.627451,0.769127,0.954867)
#  RGB{Float32}(0.43708,0.628055,0.853424)      RGB{Float32}(0.623529,0.768,0.957889)
#  RGB{Float32}(0.449546,0.630572,0.855778)     RGB{Float32}(0.635294,0.76548,0.947465)
#  RGB{Float32}(0.450444,0.631904,0.857619)     RGB{Float32}(0.639216,0.769064,0.952858)
#  RGB{Float32}(0.451444,0.631025,0.861171)  …  RGB{Float32}(0.635294,0.768022,0.950526)
#  RGB{Float32}(0.447595,0.630625,0.862289)     RGB{Float32}(0.631372,0.76447,0.946622)
#  RGB{Float32}(0.444265,0.632963,0.862025)     RGB{Float32}(0.635294,0.77263,0.95138)
#  ⋮                                         ⋱
#  RGB{Float32}(0.834726,0.851324,0.830461)     RGB{Float32}(0.266666,0.466999,0.591088)
#  RGB{Float32}(0.835024,0.858125,0.834659)  …  RGB{Float32}(0.266666,0.456574,0.607673)
#  RGB{Float32}(0.841664,0.848664,0.805795)     RGB{Float32}(0.270588,0.457194,0.61448)
#  RGB{Float32}(0.842775,0.828604,0.770001)     RGB{Float32}(0.25098,0.456439,0.599924)
#  RGB{Float32}(0.846129,0.827438,0.776333)     RGB{Float32}(0.262745,0.455455,0.57376)
#  RGB{Float32}(0.852839,0.830789,0.760205)     RGB{Float32}(0.254902,0.451428,0.578041)
#  RGB{Float32}(0.848445,0.852987,0.79876)   …  RGB{Float32}(0.27451,0.455682,0.587865)
#  RGB{Float32}(0.847125,0.856643,0.806639)     RGB{Float32}(0.270588,0.447476,0.595274)
#  RGB{Float32}(0.869199,0.847998,0.78402)      RGB{Float32}(0.27451,0.451592,0.596178)
#  RGB{Float32}(0.878034,0.850609,0.803452)     RGB{Float32}(0.30196,0.479066,0.606397)
#  RGB{Float32}(0.864592,0.862639,0.819525)     RGB{Float32}(0.305882,0.475236,0.596663)
#  RGB{Float32}(0.849594,0.849845,0.809495)  …  RGB{Float32}(0.294117,0.465194,0.585665)

# %%
# Pogledajmo kako raste kvalita
k=100
k1=k
k2=k
k3=k
RedC=Matrix(R.Q)[:,1:k1]*R.R[1:k1,invperm(R.p)]
GreenC=Matrix(G.Q)[:,1:k2]*G.R[1:k2,invperm(G.p)]
BlueC=Matrix(B.Q)[:,1:k3]*B.R[1:k3,invperm(B.p)]
colorview(RGB,RedC,GreenC,BlueC)
# Out:
# 576×768 mappedarray(RGB{Float32}, ImageCore.extractchannels, ::Array{Float32,2}, ::Array{Float32,2}, ::Array{Float32,2}) with eltype RGB{Float32}:
#  RGB{Float32}(0.441992,0.633273,0.848216)  …  RGB{Float32}(0.627447,0.774482,0.950479)
#  RGB{Float32}(0.440069,0.630371,0.85058)      RGB{Float32}(0.623531,0.775491,0.955327)
#  RGB{Float32}(0.442673,0.627031,0.857997)     RGB{Float32}(0.619608,0.771338,0.961459)
#  RGB{Float32}(0.445606,0.623401,0.859039)     RGB{Float32}(0.619608,0.76962,0.960281)
#  RGB{Float32}(0.444404,0.624118,0.859539)     RGB{Float32}(0.619608,0.771094,0.95632)
#  RGB{Float32}(0.441859,0.622729,0.856806)  …  RGB{Float32}(0.623529,0.771485,0.952257)
#  RGB{Float32}(0.442129,0.623367,0.852596)     RGB{Float32}(0.627451,0.767646,0.958387)
#  RGB{Float32}(0.437282,0.626006,0.85369)      RGB{Float32}(0.623529,0.76799,0.963164)
#  RGB{Float32}(0.446168,0.62719,0.854663)      RGB{Float32}(0.635294,0.765856,0.953445)
#  RGB{Float32}(0.448238,0.627638,0.856757)     RGB{Float32}(0.639216,0.769506,0.956084)
#  RGB{Float32}(0.450712,0.627033,0.85877)   …  RGB{Float32}(0.635294,0.767102,0.950362)
#  RGB{Float32}(0.446299,0.626776,0.857526)     RGB{Float32}(0.631372,0.763598,0.945543)
#  RGB{Float32}(0.439532,0.627591,0.859523)     RGB{Float32}(0.635294,0.771844,0.951501)
#  ⋮                                         ⋱
#  RGB{Float32}(0.873026,0.856525,0.861001)     RGB{Float32}(0.266666,0.467125,0.614989)
#  RGB{Float32}(0.867549,0.87608,0.857633)   …  RGB{Float32}(0.266666,0.472766,0.62569)
#  RGB{Float32}(0.859924,0.871749,0.807048)     RGB{Float32}(0.270588,0.473472,0.629114)
#  RGB{Float32}(0.855541,0.847383,0.754754)     RGB{Float32}(0.25098,0.459571,0.580286)
#  RGB{Float32}(0.85725,0.845192,0.739297)      RGB{Float32}(0.262745,0.450138,0.549717)
#  RGB{Float32}(0.86289,0.853321,0.777467)      RGB{Float32}(0.254902,0.446255,0.577699)
#  RGB{Float32}(0.864488,0.872002,0.834383)  …  RGB{Float32}(0.27451,0.448575,0.601206)
#  RGB{Float32}(0.865993,0.860635,0.844787)     RGB{Float32}(0.270588,0.44091,0.595464)
#  RGB{Float32}(0.885795,0.851961,0.804884)     RGB{Float32}(0.27451,0.445652,0.599841)
#  RGB{Float32}(0.895533,0.870904,0.788099)     RGB{Float32}(0.30196,0.477106,0.630959)
#  RGB{Float32}(0.887345,0.875799,0.757331)     RGB{Float32}(0.305882,0.484768,0.629805)
#  RGB{Float32}(0.86355,0.856256,0.717122)   …  RGB{Float32}(0.294117,0.470471,0.571778)
